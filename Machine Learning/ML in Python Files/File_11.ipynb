# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# i want draw bar graph for scores
scores = [80,90,60]
sub_names = ['python','c','java']

# %%
plt.bar(sub_names,scores)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar?

# %%
plt.bar(sub_names,scores)
plt.title('Subject Marks')# providing title for that figure
plt.xlabel('Subject Names')# providein x-axis name
plt.ylabel('Marks')# providing y-axis name
# Out:
# Text(0, 0.5, 'Marks')

# %%
plt.bar(sub_names,scores,color='rgb')
plt.title('Subject Marks')# providing title for that figure
plt.xlabel('Subject Names')# providein x-axis name
plt.ylabel('Marks')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
x=[1,2,3,4,5]
plt.bar(x,x)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar?

# %%
plt.pie?

# %%
plt.pie(scores,labels=sub_names)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d64833a5c0>,
# ...
#  [Text(0.5060715216253989, 0.976673750543012, 'python'),
#   Text(-1.0592090076259044, -0.2967764784549932, 'c'),
#   Text(0.7508084640855958, -0.803919554593262, 'java')])

# %%
plt.pie(scores,labels=sub_names)
plt.title('Subject Scores')
# Out:
# Text(0.5, 1.0, 'Subject Scores')

# %%
plt.pie?

# %%
plt.pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
plt.title('Subject Scores')
plt.legend()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


#labels = ['G1', 'G2', 'G3', 'G4', 'G5']
#men_means = [20, 34, 30, 35, 27]
#women_means = [25, 32, 34, 20, 25]

x = np.arange(len(sub_names))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, scores, width, label='Scores')
#rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(sub_names)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
#autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
fig=plt.figure(figsize=(8,3))
plt.subplot(121)
plt.bar(sub_names,scores,color='rgb')
plt.title('Subject Marks')# providing title for that figure
plt.xlabel('Subject Names')# providein x-axis name
plt.ylabel('Marks')
plt.legend()
plt.subplot(1,2,2)
plt.pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
plt.title('Subject Scores')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
fig=plt.figure(figsize=(8,9))
plt.subplot(211)
plt.bar(sub_names,scores,color='rgb')
plt.title('Subject Marks')# providing title for that figure
plt.xlabel('Subject Names')# providein x-axis name
plt.ylabel('Marks')
plt.legend()
plt.subplot(212)
plt.pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
plt.title('Subject Scores')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
fig=plt.figure(figsize=(8,11))
plt.subplot(221)
plt.bar(sub_names,scores,color='rgb')
plt.title('Subject Marks')# providing title for that figure
plt.xlabel('Subject Names')# providein x-axis name
plt.ylabel('Marks')
plt.legend()
plt.subplot(222)
plt.pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
plt.title('Subject Scores')
plt.legend()
plt.subplot(223)
plt.bar(sub_names,scores,color='rgb')
plt.title('Subject Marks')# providing title for that figure
plt.xlabel('Subject Names')# providein x-axis name
plt.ylabel('Marks')
plt.legend()
plt.subplot(224)
plt.pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
plt.title('Subject Scores')
plt.legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
fig,ax=plt.subplots(ncols=2,nrows=2)
fig.suptitle('my images')
ax[0,0].pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
ax[0,0].set_title('hi')
ax[0,1].pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
ax[0,1].set_title('hi1')
ax[1,0].pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
ax[1,1].pie(scores,labels=sub_names,autopct='%.1f%%',explode=[0,0.1,0],shadow=True)
plt.show()

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import pandas as pd

# Initialize Figure and Axes object
fig, ax = plt.subplots()

# Load in data
tips = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# Create violinplot
ax.violinplot(tips["total_bill"], vert=False)

# Show the plot
plt.show()

# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
tips = sns.load_dataset("tips")

# Create violinplot
sns.violinplot(x = "total_bill", data=tips)

# Show the plot
plt.show()
